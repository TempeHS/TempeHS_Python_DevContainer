# %% [markdown]
# ## Sprint 1 - Item Interactions
# Technically speaking, this stage encompasses both implementing item interactions and actually learning how to use pygame, so it'll probably involve a bit more base troubleshooting than the others as I figure out how to use the program.
#
# ### Issues
# - The tutorial I was following to try and get something basic down straight up didn't work (the program kept freezing, I couldn't initialise everything, etc), so it's probably better off if I start from scratch.

# %% [markdown]
# ## Stuff left to add
# - item interactions - WIP
# - SQL databases ('save files') - likely sprint 2, as I can just check the internal database to see if they're working
# - dialogue (as a way of showing the ability to save/load to the player)
# - loading save files
# - web support (this will probably be the last one I add, as its almost definitely going to be the hardest part to implement. Additionally, it might mess with some of the game's other features and I'd rather have these potential issues in a branch of the project than have them cause problems later)
